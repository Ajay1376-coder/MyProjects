# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:/Users/AJAY SINGH/Downloads/CC GENERAL.csv")

# %%
data
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
data['MINIMUM_PAYMENTS'].value_counts()
# Out:
# 299.351881     2
# 3.197940       1
# 111.691332     1
# 129.682608     1
# 872.760983     1
#               ..
# 1227.773229    1
# 127.210691     1
# 6422.472544    1
# 471.940554     1
# 189.459157     1
# Name: MINIMUM_PAYMENTS, Length: 8636, dtype: int64

# %%
data['MINIMUM_PAYMENTS']=data['MINIMUM_PAYMENTS'].fillna(data['MINIMUM_PAYMENTS'].median())
data=data.dropna(subset=['CREDIT_LIMIT'])

# %%
data.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
data.drop('CUST_ID',axis=1,inplace=True)
# Out:
# C:\Users\AJAY SINGH\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data.shape
# Out:
# (8949, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8949 entries, 0 to 8949
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8949 non-null   float64
#  1   BALANCE_FREQUENCY                 8949 non-null   float64
#  2   PURCHASES                         8949 non-null   float64
#  3   ONEOFF_PURCHASES                  8949 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8949 non-null   float64
#  5   CASH_ADVANCE                      8949 non-null   float64
#  6   PURCHASES_FREQUENCY               8949 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8949 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8949 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8949 non-null   float64
#  10  CASH_ADVANCE_TRX                  8949 non-null   int64
# ...

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8949.000000        8949.000000   8949.000000       8949.000000
# mean    1564.647593           0.877350   1003.316936        592.503572
# std     2081.584016           0.236798   2136.727848       1659.968851
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.365782           0.888889     39.800000          0.000000
# 50%      873.680279           1.000000    361.490000         38.000000
# 75%     2054.372848           1.000000   1110.170000        577.830000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8949.000000   8949.000000          8949.000000
# mean               411.113579    978.959616             0.490405
# std                904.378205   2097.264344             0.401360
# min                  0.000000      0.000000             0.000000
# ...

# %%
sns.distplot(data['BALANCE'])

# %%
sns.distplot(data['BALANCE_FREQUENCY'])

# %%
sns.distplot(data['PURCHASES'])

# %%
sns.distplot(data['ONEOFF_PURCHASES'])

# %%
sns.distplot(data['INSTALLMENTS_PURCHASES'])

# %%
sns.distplot(data['CASH_ADVANCE'])

# %%
sns.distplot(data['PURCHASES_FREQUENCY'])

# %%
sns.distplot(data['ONEOFF_PURCHASES_FREQUENCY'])

# %%
sns.distplot(data['PURCHASES_INSTALLMENTS_FREQUENCY'])

# %%
sns.distplot(data['CASH_ADVANCE_TRX'])

# %%
sns.boxplot(data['CASH_ADVANCE_TRX'])

# %%
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
data.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
col=['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES','INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
       'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY','CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
    'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT','TENURE']
features=data[col]

# %%
from sklearn.preprocessing import  MinMaxScaler
mi=MinMaxScaler()

# %%
data[col]=mi.fit_transform(features)
# Out:
# <ipython-input-27-36c6d2312124>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col]=mi.fit_transform(features)
# C:\Users\AJAY SINGH\anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
data
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     0.002148           0.818182   0.001945          0.000000
# 1     0.168169           0.909091   0.000000          0.000000
# 2     0.131026           1.000000   0.015766          0.018968
# 3     0.087521           0.636364   0.030567          0.036775
# 4     0.042940           1.000000   0.000326          0.000393
# ...        ...                ...        ...               ...
# 8945  0.001496           1.000000   0.005936          0.000000
# 8946  0.001007           1.000000   0.006118          0.000000
# 8947  0.001229           0.833333   0.002945          0.000000
# 8948  0.000707           0.833333   0.000000          0.000000
# 8949  0.019572           0.666667   0.022293          0.026821
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   0.004240      0.000000             0.166667
# 1                   0.000000      0.136685             0.000000
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)

# %%
from sklearn.cluster import KMeans

# %%
X=data
X
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     0.002148           0.818182   0.001945          0.000000
# 1     0.168169           0.909091   0.000000          0.000000
# 2     0.131026           1.000000   0.015766          0.018968
# 3     0.087521           0.636364   0.030567          0.036775
# 4     0.042940           1.000000   0.000326          0.000393
# ...        ...                ...        ...               ...
# 8945  0.001496           1.000000   0.005936          0.000000
# 8946  0.001007           1.000000   0.006118          0.000000
# 8947  0.001229           0.833333   0.002945          0.000000
# 8948  0.000707           0.833333   0.000000          0.000000
# 8949  0.019572           0.666667   0.022293          0.026821
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   0.004240      0.000000             0.166667
# 1                   0.000000      0.136685             0.000000
# ...

# %%
ke=KMeans(n_clusters=5,random_state=11)

# %%
model1=ke.fit(X)

# %%
model1.predict(X)
# Out:
# array([0, 0, 3, ..., 1, 0, 3])

# %%
model1.inertia_
# Out:
# 2261.7905545805056

# %%
wcss=[]
for i in range(1,13):
    ke=KMeans(n_clusters=i)
    model1=ke.fit(X)   
    model1.predict(X)
    wcss.append(model1.inertia_)

# %%
wcss
# Out:
# [5933.6123312690515,
#  3506.845909346641,
#  2926.2982679428787,
#  2550.668692168921,
#  2261.794441633209,
#  2052.1251616971276,
#  1857.4702909109544,
#  1700.5284623950831,
#  1568.8245836258413,
#  1448.2140125536257,
#  1354.2196933361706,
#  1316.7476084722412]

# %%
plt.plot(range(1,13),wcss)

# %%
### It seems like elbow is at 2

# %%
ke=KMeans(n_clusters=2)
model1=ke.fit(X)   
pred=model1.predict(X)
model1.inertia_
# Out:
# 3506.8487621110335

# %%
model1.cluster_centers_
# Out:
# array([[0.08896304, 0.82870325, 0.00659559, 0.00631332, 0.00294856,
#         0.02793557, 0.16023771, 0.09274377, 0.06626139, 0.12157277,
#         0.03508215, 0.00874502, 0.13617911, 0.02887042, 0.0107534 ,
#         0.07122087, 0.90848411],
#        [0.07386363, 0.9367283 , 0.03738135, 0.02457246, 0.03697509,
#         0.01201996, 0.89340648, 0.33642424, 0.72848001, 0.05167068,
#         0.01583651, 0.08057793, 0.16330709, 0.04064668, 0.01143214,
#         0.25444433, 0.93329198]])

# %%
from sklearn.metrics import silhouette_score

# %%
print("Accuracy of Model with 2 cluster is ",round(silhouette_score(X,ke.labels_),2))
# Out:
# Accuracy of Model with 2 cluster is  0.39

# %%
pred
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
e=pd.DataFrame({'Cluster':pred})

# %%
data_new=pd.concat([e,data],axis=1)

# %%
data_new
# Out:
#       Cluster   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0         0.0  0.002148           0.818182   0.001945          0.000000
# 1         0.0  0.168169           0.909091   0.000000          0.000000
# 2         1.0  0.131026           1.000000   0.015766          0.018968
# 3         0.0  0.087521           0.636364   0.030567          0.036775
# 4         0.0  0.042940           1.000000   0.000326          0.000393
# ...       ...       ...                ...        ...               ...
# 8945      1.0  0.001496           1.000000   0.005936          0.000000
# 8946      1.0  0.001007           1.000000   0.006118          0.000000
# 8947      0.0  0.001229           0.833333   0.002945          0.000000
# 8948      0.0  0.000707           0.833333   0.000000          0.000000
# 8949      NaN  0.019572           0.666667   0.022293          0.026821
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
sns.scatterplot(x='PURCHASES',y='INSTALLMENTS_PURCHASES',data=data_new,hue='Cluster')

# %%
sns.scatterplot(x='PRC_FULL_PAYMENT',y='BALANCE_FREQUENCY',data=data_new,hue='Cluster')
